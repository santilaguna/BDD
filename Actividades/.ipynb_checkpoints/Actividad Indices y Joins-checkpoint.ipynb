# %% [markdown]
# # Índices en Python
#
# Primero definimos nuestras tablas (esto va a venir de un `.csv`). En este ejemplo tenemos una tabla de **Personas**, otra de **Proyectos** y una relación entre ambas entidades. Cabe destacar que una persona puede trabajar en 0 o 1 proyecto, pero un proyecto puede tener más de una persona.

# %%
Personas = [
    (1, 'Persona 1'),
    (5, 'Persona 5'),
    (2, 'Persona 2'),
    (3, 'Persona 3'),
    (10, 'Persona 10'),
    (4, 'Persona 4'),
    (6, 'Persona 6'),
]

Proyectos = [
    (1, 'Proyecto 1'),
    (2, 'Proyecto 2'),
    (3, 'Proyecto 3'),
]

# Formato (id_persona, id_proyecto)
Persona_Proyecto = [
    (1, 1),
    (2, 3),
    (10, 1),
    (5, 2),
    (6, 2),
]

# %% [markdown]
# Vamos a ingresar a las personas a un BTree, pero necesitamos encadenar las hojas. Por lo mismo vamos a crear un objeto `NodoBTree`.
#
# Para utilizar un Btree, utilizaremos la librería `BTrees`. Puedes ver la documentación de la librería aquí https://pythonhosted.org/BTrees/

# %%
from BTrees.OOBTree import OOBTree

class NodoBTree:
    def __init__(self, _tupla, _siguiente=None):
        self.tupla = _tupla
        self.siguiente = _siguiente
        
    def __str__(self):
        return f'{self.tupla}'
     
t_personas = OOBTree()

for persona in Personas:
    t_personas.update({ persona[0]: NodoBTree(persona) })

# Tenemos que generar una lista con las llaves ordenadas 
# para poder encadenar las hojas
llaves = list(t_personas.keys())
llaves.sort()

# Encadenamos las hojas
for i in range(1, len(llaves)):
    t_personas[llaves[i - 1]].siguiente = t_personas[llaves[i]]
    
# Recorremos el árbol partiendo por la primera persona
persona_actual = t_personas[t_personas.minKey()]
print(persona_actual)
while persona_actual.siguiente:   
    persona_actual = persona_actual.siguiente
    print(persona_actual)
# Out:
# (1, 'Persona 1')
# (2, 'Persona 2')
# (3, 'Persona 3')
# (4, 'Persona 4')
# (5, 'Persona 5')
# (6, 'Persona 6')
# (10, 'Persona 10')

# %% [markdown]
# Vamos a repetir el procedimiento para la relación, indexando en un árbol para el `id_persona`.

# %%
t_relacion = OOBTree()

for elemento in Persona_Proyecto:
    t_relacion.update({ elemento[0]: NodoBTree(elemento) })
    
# Tenemos que generar una lista con las llaves ordenadas 
# para poder encadenar las hojas
llaves = list(t_relacion.keys())
llaves.sort()

# Encadenamos las hojas
for i in range(1, len(llaves)):
    t_relacion[llaves[i - 1]].siguiente = t_relacion[llaves[i]]

# %% [markdown]
# Mientras que los proyectos son indexados con un Hash

# %%
h_proyectos = dict()

for proyecto in Proyectos:
    h_proyectos[proyecto[0]] = proyecto
    
# Imprimimos los proyectos
for p_key in h_proyectos.keys():
    print(h_proyectos[p_key])
# Out:
# (1, 'Proyecto 1')
# (2, 'Proyecto 2')
# (3, 'Proyecto 3')

# %% [markdown]
# Ahora escribiremos el algoritmo que hará el *join* entre las tres relaciones.

# %% [markdown]
# ------
# # Actividad - Algoritmos Join
#
# ## Esquema
#
# Para esta actividad trabajaremos con el siguiente esquema:
#
# * Usuarios(<u>id</u>, nombre)
# * Favoritos(<u>userId,movieId</u>)
# * Peliculas(movieId, title, genres)
#
# Estas tablas se encuentran en los archivos `usuarios.csv`, `favoritos.csv` y `peliculas.csv`, respectivamente. Hay dos versiones de esta base de datos, una pequeña y una grande, almacenadas en las carpetas `small` y `big` respectivamente.
#
#
# ```
# SELECT usuarios.nombre, peliculas.titulo, favorito.rating
# FROM usuarios, peliculas, favoritos
# WHERE usuarios.id = favoritos.userId AND favoritos.movieID = peliculas.movieId
# ```

# %% [markdown]
# ## Parte 1: Cargar y poblar árboles
# La primera parte será para poblar nuestras estrcturas con nuestros datos. En específico deberás realizar los siguiente:
#
# * Cargue los `csv` de acuerdo al esquema, para esta parte puedes usar simplemente los que se encuentran en la carpeta `small`.
# * Genere árboles para usuarios y ratings.
# * Genere un `Hash` para películas.

# %%
# Código que carga los csv
import pandas as pd

usuarios = pd.read_csv("small/usuarios.csv", error_bad_lines=False)   # "big/nombres_b.csv"
favoritos = pd.read_csv("small/favoritos.csv", error_bad_lines=False)  # "big/favoritos.csv"
peliculas = pd.read_csv("small/movies.csv", error_bad_lines=False)   # "big/movies.csv"

# a = [tuple(x) for x in usuarios.values]

# %%
# Código que genera los árboles
def relacionar(llaves, tree):
    llaves.sort()
    for i in range(1, len(llaves)):
        tree[llaves[i - 1]].siguiente = tree[llaves[i]]

usuarios_tree = OOBTree()
for index, row in usuarios.iterrows():
    usuarios_tree.update({row.id: NodoBTree((row.id, row.nombre))})
    
relacionar(list(usuarios_tree.keys()), usuarios_tree)
    
favoritos_tree = OOBTree()
for index, row in favoritos.iterrows():
    favoritos_tree.update({row.userID: NodoBTree((row.userID, row.movieId))})
    
relacionar(list(favoritos_tree.keys()), favoritos_tree)

# %%
# Código que genera el hash
peliculas_hash = {p.movieId : (p.title, p.genres) for i, p in peliculas.iterrows()}

# %% [markdown]
# ## Parte 2: Algoritmos
# En esta parte, deberás ir programando los algoritmos necesarios para ejecutar la operación `Join` utilizando un BTree. En concreto esto es lo que deberás hacer.
#
# ### Parte 2.1: Intersección
# Considera las dos listas definidas en el códogo a continuación. Estas listas representan dos relaciones unarias `R` y `S`. Escriba un algoritmo que imprima la intersección entre estas dos tablas, y que pase una sola vez por cada elemento.

# %%
R = [1, 2, 3, 6, 7, 10, 11, 12]
S = [1, 2, 4, 8, 10, 13, 14]

# Código que imprime la intersección
# Asumiremos que las listas están ordenadas
r_iterator = iter(R)
s_iterator = iter(S)
current_r = next(r_iterator)
current_s = next(s_iterator)
while r_iterator or s_iterator:
    try:
        if current_r == current_s:
            print(current_r)
            current_r = next(r_iterator)
            current_s = next(s_iterator)
        elif current_r < current_s:
            current_r = next(r_iterator)
        else:
            current_s = next(s_iterator)
    except StopIteration:
        break
# Out:
# 1
# 2
# 10

# %% [markdown]
# ### Parte 2.2: Join entre dos relaciones
#
# Extienda el algoritmo anterior para hacer un `Join` entre usuarios y rating en `userId` que solo pase una vez por cada tupla de cada relación

# %%
# Código que genera un Join entre usuarios y ratings
# usuarios_tree, favoritos_tree

    
#actual = usuarios_tree[usuarios_tree.minKey()]
#print(actual)
#while actual.siguiente:   
#    actual = actual.siguiente
#    print(persona_actual)
usuario_actual = usuarios_tree[usuarios_tree.minKey()]
favorito_actual = favoritos_tree[favoritos_tree.minKey()]
print("nombre usuario |", "id película favorita")
while usuario_actual and favorito_actual:
    if usuario_actual.tupla[0] < favorito_actual.tupla[0]:
        usuario_actual = usuario_actual.siguiente
    elif usuario_actual.tupla[0] > favorito_actual.tupla[0]:
        favorito_actual = favorito_actual.siguiente
    else:
        print((usuario_actual.tupla[1], favorito_actual.tupla[1]))
        usuario_actual = usuario_actual.siguiente
        favorito_actual = favorito_actual.siguiente
# Out:
# nombre usuario | id película favorita
# ('Szilard Onillon', 5060)
# ('Jamaica Ashpole', 131724)
# ('Norik Climpson', 72378)
# ('Virginica Sparshott', 4967)
# ('Shawnna Radnall', 608)
# ('Fulgencio Mullett', 1084)
# ('Nevenka Stewert', 49824)
# ('Adelmo Milson', 597)
# ('Crystal Rowson', 6044)
# ('Nathanial Windley', 140110)
# ('Anouar Cock', 2028)
# ('Ervin Hartwright', 63992)
# ('Martires Dingle', 4148)
# ('Yiying Terow', 784)
# ('Jalisa Dwyer', 166635)
# ('Rafa Theophilus', 91529)
# ('Dame Biggin', 82459)
# ('Haidee Pares', 185135)
# ('Nector Rundle', 3839)
# ('Alvydas Micklewright', 6365)
# ('Keith Huckel', 173307)
# ('Tyisha Kearvell', 74789)
# ('Klaus Pillinger', 8961)
# ('Shirly Ferns', 139385)
# ('Matilde McDowall', 187593)
# ('Cuiying Horracks', 593)
# ('Chau Reiley', 5060)
# ('Leyla Levett', 72998)
# ('Sidiki Hewday', 111759)
# ('Josimar Trewartha', 122904)
# ('Oumy Plester', 5060)
# ('Mariano Faux', 1459)
# ('Lofti Ashbrood', 2943)
# ('Amberly Hitchings', 45499)
# ('Rosina OMaley', 595)
# ('Monsif Groundwater', 6662)
# ('Kermit Winkley', 1073)
# ('Arvilla Gorse', 736)
# ('Jonhatan Clover', 3911)
# ('Loreta Copple', 685)
# ('Genie Ewbank', 150548)
# ('Grettel Keight', 4686)
# ('Pino Gailey', 1356)
# ('Xuehong Howey', 1639)
# ('Nati Holgate', 54286)
# ('Betina Biltcliffe', 595)
# ('Zambra Wittleton', 171011)
# ('Puiu Hagen', 8636)
# ('Vladislav Hesket', 168252)
# ('Moner Fernee', 190183)
# ('Guiayara Doyle', 60487)
# ('Ghulam Dadswell', 152081)
# ('Laurea Mullet', 4019)
# ('Editha Pugh', 639)
# ('Murat Dunckley', 54286)
# ('Genara Rodley', 786)
# ('Bilaly Baugh', 5060)
# ('Abdessamad Pendrey', 1073)
# ('Shujing Orton', 6460)
# ('Fidencia Summerson', 58559)
# ('Johanny Flemming', 30707)
# ('Fekri Key', 187595)
# ('Fatemeh Downton', 134853)
# ('Jazael Nickols', 46578)
# ('Joannie Bolderson', 122904)
# ('Shaomei Lowen', 51255)
# ('Airong Hilbert', 152081)
# ('Norris Corling', 176371)
# ('Pedrona Farigerty', 4963)
# ('Ipar Moriarthy', 91077)
# ('Estelle Brewer', 1544)
# ('Lucindo Batt', 56174)
# ('Raymundo Worswick', 152081)
# ('Ievgeniia Busill', 58154)
# ('Stanko McGeorge', 44199)
# ('Petrica Halksworth', 117176)
# ('Ryad Lay', 109487)
# ('Caroll Markillio', 68791)
# ('Frans Minney', 4005)
# ('Lukman Hyton', 103688)
# ('Martyna Perfect', 592)
# ('Cathey Nellis', 7325)
# ('Bernd Burbery', 88125)
# ('Malen Boult', 5060)
# ('Marquita Alfrey', 1747)
# ('Margareta Vinicombe', 95510)
# ('Raheela Denney', 7022)
# ('Janean Joslyen', 83177)
# ('Mervin Bezzant', 184791)
# ('Yanjun Daxon', 1442)
# ('Soukeina Whitlaw', 31696)
# ('Blasida Covel', 69757)
# ('Suling Skerratt', 2968)
# ('Manju Thomas', 597)
# ('Takako Lowes', 8644)
# ('Aijun Eldridge', 3819)
# ('Mustansar Connelley', 5420)
# ('Ysidro Tomkis', 187593)
# ('Wenli Adkinson', 592)
# ('Safeer MacDougall', 8636)
# ('Itzal Forty', 3793)
# ('Aleksej Twyford', 802)
# ('Faride Ennor', 168250)
# ('Lida Dockrill', 114180)
# ('Maryury Beach', 179133)
# ('Arafat Ascroft', 112852)
# ('Dalibor Middleditch', 590)
# ('Voicu Bewsher', 6049)
# ('Abderrezak Rawdens', 1033)
# ('Pandava Manwaring', 47629)
# ('Pieter Nuttycombe', 184257)
# ('Terica Bossom', 115617)
# ('Yeison Corkhill', 4130)
# ('Daren Olliman', 167732)
# ('Yandira Hodsall', 3793)
# ('Khadidjetou Rex', 62383)
# ('Marouan Fall', 1079)
# ('Sobeida Mill', 2918)
# ('Enekoitz Waudby', 168252)
# ('Libbie Evison', 1367)
# ('Henrietta Tingley', 780)
# ('Shawna Gomm', 152081)
# ('Celestina Patten', 143458)
# ('Asya Beirne', 79592)
# ('Tejinder Denmead', 176371)
# ('Jianxiong Gambier', 595)
# ('Mounya Slaytor', 68954)
# ('Abdelkhalek Handy', 1721)
# ('Ozell Ransom', 49649)
# ('Mauricio Openshaw', 595)
# ('Stein Hardisty', 91529)
# ('Yolande Temperton', 79132)
# ('Myrian Jenkyns', 1036)
# ('Lidan Caple', 595)
# ('Nena Windass', 4993)
# ('Alexi Janes', 688)
# ('Alaina Henbest', 33493)
# ('Adelto Shoesmith', 59784)
# ('Romualdo Wovencraft', 122892)
# ('Lirong Terry', 53972)
# ('Heraclides Mallett', 139385)
# ('Quilen Magnall', 595)
# ('Vikas Angell', 106696)
# ('Boubaker Grinrod', 27416)
# ('Drina Rixen', 595)
# ('Ambrosio Trudgian', 58803)
# ('Soraida Atkin', 2699)
# ('Moacir Widdicombe', 160718)
# ('Eustaquia Keye', 2094)
# ('Viacheslav Dunken', 1356)
# ('Macario Hatherton', 1432)
# ('Bhaga Grimston', 116897)
# ('Randy Sibson', 184471)
# ('Carletta Mackesfield', 164179)
# ('Queralt Walkear', 3793)
# ('Porsha Pendal', 31038)
# ('Yugo Dentery', 3752)
# ('Vito Wigglesworth', 66320)
# ('Yave Dakers', 166643)
# ('Idelfonsa Kerley', 7153)
# ('Mamadi Winpenny', 52287)
# ('Ineso Labourn', 802)
# ('Dulcelina Ide', 1837)
# ('Idell Downing', 4440)
# ('Danel Speechley', 6188)
# ('Gracia Skewis', 55232)
# ('Aizhen Naphthen', 47122)
# ('Salwa Pullen', 85881)
# ('Abdramane Bolson', 8783)
# ('Jesse Bethell', 736)
# ('Loic Aufield', 5060)
# ('Clair Bundock', 7438)
# ('Ramadan Barnes', 597)
# ('Emre Roney', 780)
# ('Geovanna Skikelthorpe', 58107)
# ('Macrina Sandison', 780)
# ('Prudence Olliman', 123545)
# ('Prosper Massam', 44195)
# ('Guayasen Setterfield', 1061)
# ('Lucinia Gorse', 4993)
# ('Pandu Barnet', 1084)
# ('Radita Bowlin', 44204)
# ('Medarda Caley', 4085)
# ('Kimiko Wharton', 193587)
# ('Achour Trowbridge', 5952)
# ('Cathleen Conlin', 5540)
# ('Jinli Nussey', 52328)
# ('Jurate Noblett', 5060)
# ('Almira Patton', 91529)
# ('Anabell Doubt', 116823)
# ('Berit Sircombe', 720)
# ('Yufen Eckels', 593)
# ('Itoitz Abdalraman', 97938)
# ('Sabira Bullivant', 7143)
# ('Ouiza Sorge', 5254)
# ('Dong Boot', 142488)
# ('Brandon Farwell', 3072)
# ('Blossom Michel', 5607)
# ('Venita Winders', 69481)
# ('Trifonia Whittemore', 63433)
# ('Nikoloz Brown', 2918)
# ('Krassimira Akenhead', 5060)
# ('Winford Dummett', 98809)
# ('Nohemy Jonathan', 91658)
# ('Tolentina Lightfoot', 179817)
# ('Mamun Claydon', 1356)
# ('Narciso Kimmins', 3740)
# ('Shanita Treadwell', 2916)
# ('Julius Wapplington', 185029)
# ('Billel Durdy', 189547)
# ('Verlie Blackshaw', 95510)
# ('Olguta Cubitt', 188751)
# ('Fettoum Watchorn', 89582)
# ('Ouafaa Hick', 1409)
# ('Anghel Woody', 72407)
# ('Hanan Hunking', 4036)
# ('Egiarte Pierson', 6425)
# ('Deb Griggs', 8636)
# ('Xiangmei Donnolly', 66297)
# ('Egidijus Beels', 71264)
# ('Zenobio Spesier', 34048)
# ('Houriya Poutney', 106916)
# ('Isoken Bennet', 58559)
# ('Chun Grey', 3948)
# ('Romain Thorp', 5060)
# ('Suyun Pellin', 59784)
# ('Waled Neblick', 134853)
# ('Tanesha Moulden', 60069)
# ('Aparicio Dewsnap', 736)
# ('Manja Brentnall', 55553)
# ('Eleazar Furnish', 109487)
# ('Artemio Galston', 82459)
# ('Wladimiro Cotter', 187593)
# ('Katalin Woolterton', 4638)
# ('Tressa Meloy', 780)
# ('Majid Leedale', 3052)
# ('Laie Clee', 106782)
# ('Erick Kennard', 4958)
# ('Raimundo Groundale', 61350)
# ('Ghada Camerone', 1367)
# ('Cañosanto Chatwin', 134853)
# ('Chima Boylan', 593)
# ('Isela Trollope', 736)
# ('Zamfir Fuell', 3811)
# ('Buba Drennan', 3274)
# ('Loriann Bigland', 96079)
# ('Lluc Bromel', 152081)
# ('Anthonia Barnstien', 189333)
# ('Beneamin Berkly', 187593)
# ('Abdelmaoula Meadow', 8880)
# ('Luzdivino Nichols', 159817)
# ('Shera Melish', 168418)
# ('Yingmei Wincott', 72998)
# ('Liceth Fitt', 49530)
# ('Melodee Tolley', 4480)
# ('Alassane Payton', 146024)
# ('Rosaria Penfold', 5952)
# ('Carme Spaven', 122918)
# ('Valeska Thirlwell', 7361)
# ('Nazira Salvi', 30810)
# ('Jamila Burnell', 112138)
# ('Millan Broomham', 728)
# ('Ayan Cairns', 33679)
# ('Rafiq Nowlen', 41566)
# ('Guihua Avent', 3844)
# ('Amparito Brammer', 3265)
# ('Avigail Haw', 4033)
# ('Severino Luke', 2973)
# ('Odeta Jeffreyes', 1367)
# ('Leopoldina Dawton', 1356)
# ('Diawara Kerr', 55765)
# ('Pauna Wear', 177765)
# ('Sinforosa Boyes', 783)
# ('Artur Deyns', 86911)
# ('Nika Greenham', 6254)
# ('Belaid Wilder', 1391)
# ('Lele Cotterill', 1429)
# ('Latonya Cunliffe', 54272)
# ('Harm Clinch', 175303)
# ('Waldo Thompson', 96821)
# ('Jordana Scruse', 51662)
# ('Wioleta Siddell', 139385)
# ('Kizkitza Mayfield', 2124)
# ('Pervaiz Liversige', 736)
# ('Dan Jefferies', 113207)
# ('Rimma Gainford', 8961)
# ('Annette Linney', 27822)
# ('Crescenciana George', 72998)
# ('Geertruida Smee', 26704)
# ('Abdelkabir Egerton', 3849)
# ('Jurgen Napier', 134853)
# ('Viva Corkhill', 166528)
# ('Huey Branthwaite', 5313)
# ('Donvina Howarth', 3877)
# ('Nasiha Radcliffe', 79132)
# ('Amale Danson', 180031)
# ('Slavomir Loweth', 2952)
# ('Martirian Farmery', 158238)
# ('Veaceslav Morecroft', 3793)
# ('Pam Grey', 112556)
# ('Prakash Cavins', 56788)
# ('Luiz Cobby', 1221)
# ('Antia Lund', 6333)
# ('Monte Newnes', 5060)
# ('Artesino Bower', 187593)
# ('Confesor Gillgrass', 183295)
# ('Joaquima Woodbridge', 69122)
# ('Jekaterina Pask', 117192)
# ('Badredin Berkly', 48780)
# ('Elissa Ithell', 7305)
# ('Roso Sharples', 6561)
# ('Hayat Selley', 5991)
# ('Chantell Keighley', 5544)
# ('Boutaina Damafin', 1391)
# ('Shujing Reney', 2951)
# ('Ferrer Marples', 8622)
# ('Junia Baldrans', 133115)
# ('Virginijus Bailey', 189381)
# ('Rokhaya Boney', 152081)
# ('Otha Cleet', 72998)
# ('Valdecir Offord', 802)
# ('Hermosinda Lindop', 60040)
# ('Riad Bowden', 117176)
# ('Jenniffer Huckings', 3979)
# ('Aniol Wearing', 5980)
# ('Aitxiber Abray', 146656)
# ('Iray Danson', 58559)
# ('Krisztina Woollard', 166643)
# ('Jinying Delaforce', 136850)
# ('Nadir Watchman', 79702)
# ('Rudolf Florendine', 193609)
# ('Eladino Sarge', 97757)
# ('Harun Liddle', 3826)
# ('Wentao Goulder', 76093)
# ('Ludibia Pendrey', 3911)
# ('Bobbye Balchin', 38798)
# ('Traute Carpenter', 1393)
# ('Olayo Pippin', 190221)
# ('Jenifer Paver', 176751)
# ('Evangeline Herdman', 1356)
# ('Himad Spracklan', 136020)
# ('Mittie Umbers', 5099)
# ('Laxmi Ashmole', 56367)
# ('Llara Leaker', 114180)
# ('Teisha Bonython', 56949)
# ('Sonia Threadkill', 48394)
# ('Gelasio Lancashire', 780)
# ('Yongfeng Newbery', 92259)
# ('Deidra Askham', 597)
# ('Yimmy Coatman', 1393)
# ('Manisha Egerton', 92422)
# ('Ciaran Nieass', 166528)
# ('Eydan Harrap', 595)
# ('Kanchan Hobson', 56174)
# ('Deetta Brewster', 3548)
# ('Rongsheng Hiscocks', 67734)
# ('Tamaz Crankshaw', 96563)
# ('Hassan MackDonald', 89386)
# ('Mehdia Jeffreys', 55247)
# ('Danail Haylock', 1754)
# ('Kim Jermy', 56775)
# ('Alegra Kynaston', 175303)
# ('Fundador Peak', 176579)
# ('Parascovia Egcumbe', 1356)
# ('Angelberto Bawden', 165947)
# ('Blanca World', 122882)
# ('Nadra Comber', 4700)
# ('Iruña Hyne', 5060)
# ('Cassio Buckham', 60069)
# ('Kiana Twigg', 44195)
# ('Catheryn Climenson', 112512)
# ('Izai Diggle', 5060)
# ('Yoana Scanes', 736)
# ('Marylene Callicott', 1356)
# ('Guomin Lynham', 48385)
# ('Ta Broadfield', 98961)
# ('Bonifacio Lawday', 94262)
# ('Yolando Hutchings', 116797)
# ('Awais Mortimer', 597)
# ('Tamila Treglown', 188301)
# ('Suhail Holt', 78893)
# ('Pavel Hutt', 170289)
# ('Auicha Thursfield', 3115)
# ('Mikkel Kirsopp', 4396)
# ('Villaviciosa Abbis', 5060)
# ('Elihu Kidgell', 786)
# ('Almiro Townend', 59727)
# ('Legarda Northway', 104245)
# ('Milagros Blewett', 1356)
# ('Hesham Dutton', 66097)
# ('Ralf Golding', 5575)
# ('Yanhua Leeves', 4085)
# ('Cyrille Duffy', 130842)
# ('Yolonda Anstead', 595)
# ('Abdelkhalek Perry', 1032)
# ('Micheline Dancey', 6377)
# ('Yongjie Handly', 44555)
# ('Letisha Horracks', 82459)
# ('Ludivine Morgan', 33794)
# ('Aime Bramham', 168252)
# ('Zuleica Lewsky', 170939)
# ('Messoud Wickens', 1084)
# ('Hinda Hender', 62081)
# ('Jonelle Gigney', 597)
# ('Gerlinde Joslin', 79132)
# ('Mirjam Gatley', 56949)
# ('Raissa Baskerville', 112556)
# ('Haiou Pudsey', 166528)
# ('Viviane Worledge', 5060)
# ('Andere Cockett', 6460)
# ('Vinod Aconley', 708)
# ('Salete Barry', 2935)
# ('Inca Fildes', 128360)
# ('Chunling Timmis', 187595)
# ('Lauro William', 99114)
# ('Elenore Bromiley', 46976)
# ('Aragones Hindle', 187541)
# ('Polonio Geddis', 156387)
# ('Eufemia Saxton', 98961)
# ('Maryann Bricker', 62956)
# ('Ascencion Yard', 81845)
# ('Zurine Denyer', 5063)
# ('Abdourahmane Such', 5445)
# ('Garnik Lichfield', 136469)
# ('Eduard Messer', 79132)
# ('Eustoquio Diver', 94959)
# ('Pool Mullard', 6349)
# ('Isamael Carylon', 27846)
# ('Emperatriz Tillford', 595)
# ('Gervasia Sawtell', 66097)
# ('Macie Goble', 3948)
# ('Reidar Pattin', 92391)
# ('Ramiz Hampton', 174055)
# ('Mellissa Totty', 74458)
# ('Lorrie Ivy', 82459)
# ('Ahmad Medley', 720)
# ('Biagio Oldknow', 1488)
# ('Windy Yardley', 51662)
# ('Zviadi Joule', 98809)
# ('Idy Cruwys', 60069)
# ('Nathaniel Leveredge', 122886)
# ('Jaymie Willmer', 4361)
# ('Garland Pizey', 116823)
# ('Yufei Sugars', 595)
# ('Janee Dunbill', 116897)
# ('Fatima Thrupp', 780)
# ('Shah Faircloth', 597)
# ('Rachal Lightowler', 173751)
# ('Kostadinka Huxley', 5952)
# ('Janny Abdalraman', 3977)
# ('Alisha Ollis', 1356)
# ('Ahitana Horsfield', 6537)
# ('Milcho Myatt', 5876)
# ('Faina Whittemore', 79008)
# ('Blythe Warmington', 597)
# ('Season Callaghan', 1407)
# ('Pauna Fancutt', 3897)
# ('Cilene Breitenstein', 1073)
# ('Meryam Gunn', 177765)
# ('Hazel Haylock', 89039)
# ('Beckie Woodthorpe', 106782)
# ('Alberte Brinkworth', 189713)
# ('Rochelle Rucastle', 36529)
# ('Yamil Bannin', 90384)
# ('Nezar Ivison', 5060)
# ('Haiguang Seary', 116797)
# ('Hanifa Holburn', 2493)
# ('Shuangyan Gadsby', 595)
# ('Bhima Northena', 6460)
# ('Johna Chrishop', 1073)
# ('Husein Haddock', 168252)
# ('Sorangel Badder', 95510)
# ('Florentino Morry', 48385)
# ('Evelio Fake', 66934)
# ('Ottavio Bawn', 168252)
# ('Abdourahamane Stoakes', 616)
# ('Ayala Worroll', 82242)
# ('Ashli Morton', 34048)
# ('Sidy Corby', 5938)
# ('Atsegiñe Grenet', 53000)
# ('Lingjun Parkhouse', 1729)
# ('Fania Gown', 30825)
# ('Georgann Plumbley', 115065)
# ('Aizhen Bavage', 93510)
# ('Gail Daykin', 593)
# ('Barbera Branch', 780)
# ('Hector Keyte', 116797)
# ('Nadifa Hortop', 30707)
# ('Marianna McEvry', 98809)
# ('Brunella Hingod', 91658)
# ('Haroldo Stopps', 180231)
# ('Sohel Donner', 1499)
# ('Latviešu Boocock', 4701)
# ('Youssif McGovan', 4498)
# ('Husein Gannon', 148626)
# ('Bennaceur Coogan', 114713)
# ('Tomasz Draffen', 131739)
# ('Tudorel Dowse', 648)
# ('Inam Beanland', 56286)
# ('Gersom Emberton', 4873)
# ('Hrachya Westmacott', 849)
# ('Teresa Druggan', 8529)
# ('Alisea Pickrell', 94130)
# ('Kestutis Ridgeon', 7153)
# ('Daniele Bretton', 74685)
# ('Hilaria Wath', 112852)
# ('Encarnacio Ayres', 595)
# ('Guizlane Tonking', 3396)
# ('Clemmie Lindridge', 136840)
# ('Carminda Hazel', 40819)
# ('Renata Gerarty', 164179)
# ('Marise Plum', 597)
# ('Sirley Dyar', 7153)
# ('Isidre Quarry', 188797)
# ('Kiesha Battams', 179819)
# ('Bahia Brougham', 4429)
# ('Joseba Whitefield', 167746)
# ('Morelia Wyon', 6377)
# ('Edson Hosking', 140110)
# ('Diamela Minson', 81845)
# ('Yer Kenworthy', 1073)
# ('Tara Vanderkisle', 127098)
# ('Monique Keet', 168252)
# ('Simeona Rickaby', 2019)
# ('Neiba Messum', 164540)
# ('Kizzy Timothy', 176415)
# ('Sumiko Foreman', 5560)
# ('Marika Chinery', 106782)
# ('Candyce Chrishop', 1073)
# ('Abdeljaouad Hinchcliffe', 597)
# ('Jayne Moah', 5349)
# ('Beatris Udall', 4863)
# ('Lazara Foules', 127096)
# ('Jonah Beadling', 164367)
# ('Domiciana Moir', 2882)
# ('Roksana Trathan', 593)
# ('Dipa Eccles', 121129)
# ('Catherina Metcalf', 81845)
# ('Lannie Cillinsona', 89864)
# ('Rogelia Laycock', 48516)
# ('Iulius Bulter', 745)
# ('Sani Weakham', 48780)
# ('Jenara Bamford', 101765)
# ('Gherghina Hepplewhite', 1356)
# ('Iulica Elmer', 63853)
# ('Celso Bardell', 3985)
# ('Eddy Faris', 3102)
# ('Rongjun Escoline', 168712)
# ('Laura Allies', 158813)
# ('Xiangyu McLay', 167296)
# ('Leslee Warmington', 170697)
# ('Momodou Spier', 7361)
# ('Min Kesteven', 61257)
# ('Martha Raikes', 3168)
# ('Abdelkamel Stockman', 6184)
# ('Khachatur Mirfield', 187031)
# ('Leisy Silby', 134130)
# ('Jianping Cumberbatch', 5420)
# ('Cleiton Sargison', 1580)
# ('Liboria Ironmonger', 155288)
# ('Chaker Hall', 168174)
# ('Giulio Willington', 100306)
# ('Yenny Brien', 139747)
# ('Delores Cooknell', 160271)
# ('Saba Daxon', 597)
# ('Hossnia Tollaway', 1027)
# ('Roselina McDowall', 184253)
# ('Danylo Brockwell', 65088)
# ('Soterraña Bosanko', 595)
# ('Lah Udall', 53125)
# ('X Stanton', 3840)
# ('Abelardo Holme', 3552)
# ('Dame Gibbard', 112852)
# ('Wahida Flaherty', 595)
# ('Racquel Seaward', 2629)
# ('Tawny Cleveland', 3082)
# ('Michale Rule', 5060)
# ('Snezha Gallafent', 81845)
# ('Maggie Nield', 3717)
# ('Detelin Harvie', 56174)
# ('Claris Lambrick', 134130)
# ('Eleodoro Backhouse', 134130)
# ('Ilse Belles', 149354)
# ('Olallo Pharaoh', 736)
# ('Nafissatou Poles', 81932)
# ('Junfen Colesworthy', 187595)
# ('Azman Gwyon', 3471)
# ('Elroy Malarney', 778)
# ('Mandeep Pullin', 1173)
# ('Sen Robinson', 82459)
# ('Misericordia Bonnington', 3916)
# ('Liwei Marriot', 788)
# ('Izar Paradine', 53464)
# ('Romano Christy', 31433)
# ('Mirelys Seccombe', 2770)
# ('Marieke Troughton', 188301)
# ('Rosia Spragg', 5060)
# ('Samar Warrell', 130490)
# ('Mehak Pawsey', 183301)
# ('Azeddin Youens', 66097)
# ('Odila Stigwood', 177765)
# ('Xiuyu Dupny', 861)
# ('Zaka Swindell', 6184)
# ('Aniria Patching', 742)
# ('Ubalda Gerrish', 78105)
# ('Moreyba Geard', 98243)
# ('Luciano Gunton', 5060)
# ('Daniil Hopekirk', 54503)
# ('Alhaji Ellett', 1161)
# ('Yiwei Mortiboys', 170875)

# %% [markdown]
# # Parte 3: Programando una consulta
#
# Ahora, extenderemos nuestros `Joins` programados para que tengan la capacidad de realizar consultas como en `sql`. Deberán poder realizar la siguiente consulta:
#
# ```
# SELECT usuarios.nombre, favoritos.userId, favoritos.movieID, pelicula.titulos
# FROM usuarios, peliculas, favoritos
# WHERE usuarios.id = favoritos.userId AND favoritos.movieID = peliculas.movieId
# ```
#
# Lo que deben programar es la funcion `join_tablas(usuarios,peliculas,favoritos)`, que reciba las tres estructuras creadas inicialmente (los árboles y el hash), y retorne una lista de de tuplas.
# Cada tupla debe ser de la forma `(nombre_usuario, userId, movieID, titulo_película)`. La idea es que se utilice el *hash join* para extender la información de cada pelicula con la que hace match.

# %%
# Aquí deberían crear la función join_tablas(usuarios,peliculas,favoritos):

def join_tablas(usuarios_tree, peliculas_hash, favoritos_tree):
    
    usuario_actual = usuarios_tree[usuarios_tree.minKey()]
    favorito_actual = favoritos_tree[favoritos_tree.minKey()]
    ret = []
    while usuario_actual and favorito_actual:
        if favorito_actual.tupla[1] in peliculas_hash and usuario_actual.tupla[0] == favorito_actual.tupla[0]:
            # (nombre_usuario, userId, movieID, titulo_película)
            ret.append(
                (usuario_actual.tupla[1], usuario_actual.tupla[0], favorito_actual.tupla[1], 
                 peliculas_hash[favorito_actual.tupla[1]][0])
            )
            usuario_actual = usuario_actual.siguiente
            favorito_actual = favorito_actual.siguiente
        elif usuario_actual.tupla[0] < favorito_actual.tupla[0]:
            usuario_actual = usuario_actual.siguiente
        else:
            favorito_actual = favorito_actual.siguiente
    return ret

# %%
# Sección para probar el output de su función

retorno_consulta = join_tablas(usuarios_tree, peliculas_hash, favoritos_tree)
print(retorno_consulta)
# Out:
# [('Szilard Onillon', 1, 5060, 'M*A*S*H (a.k.a. MASH) (1970)'), ('Jamaica Ashpole', 2, 131724, 'The Jinx: The Life and Deaths of Robert Durst (2015)'), ('Norik Climpson', 3, 72378, '2012 (2009)'), ('Virginica Sparshott', 4, 4967, "No Man's Land (2001)"), ('Shawnna Radnall', 5, 608, 'Fargo (1996)'), ('Fulgencio Mullett', 6, 1084, 'Bonnie and Clyde (1967)'), ('Nevenka Stewert', 7, 49824, 'Dreamgirls (2006)'), ('Adelmo Milson', 8, 597, 'Pretty Woman (1990)'), ('Crystal Rowson', 9, 6044, 'Blind Date (1984)'), ('Nathanial Windley', 10, 140110, 'The Intern (2015)'), ('Anouar Cock', 11, 2028, 'Saving Private Ryan (1998)'), ('Ervin Hartwright', 12, 63992, 'Twilight (2008)'), ('Martires Dingle', 13, 4148, 'Hannibal (2001)'), ('Yiying Terow', 14, 784, 'Cable Guy, The (1996)'), ('Jalisa Dwyer', 15, 166635, 'Passengers (2016)'), ('Rafa Theophilus', 16, 91529, 'Dark Knight Rises, The (2012)'), ('Dame Biggin', 17, 82459, 'True Grit (2010)'), ('Haidee Pares', 18, 185135, 'Sherlock - A Study in Pink (2010)'), ('Nector Rundle', 19, 3839, 'Phantasm IV: Oblivion (1998)'), ('Alvydas Micklewright', 20, 6365, 'Matrix Reloaded, The (2003)'), ('Keith Huckel', 21, 173307, 'The Gracefield Incident (2015)'), ('Tyisha Kearvell', 22, 74789, 'Alice in Wonderland (2010)'), ('Klaus Pillinger', 23, 8961, 'Incredibles, The (2004)'), ('Shirly Ferns', 24, 139385, 'The Revenant (2015)'), ('Matilde McDowall', 25, 187593, 'Deadpool 2 (2018)'), ('Cuiying Horracks', 26, 593, 'Silence of the Lambs, The (1991)'), ('Chau Reiley', 27, 5060, 'M*A*S*H (a.k.a. MASH) (1970)'), ('Leyla Levett', 28, 72998, 'Avatar (2009)'), ('Sidiki Hewday', 29, 111759, 'Edge of Tomorrow (2014)'), ('Josimar Trewartha', 30, 122904, 'Deadpool (2016)'), ('Oumy Plester', 31, 5060, 'M*A*S*H (a.k.a. MASH) (1970)'), ('Mariano Faux', 32, 1459, 'Absolute Power (1997)'), ('Lofti Ashbrood', 33, 2943, 'Indochine (1992)'), ('Amberly Hitchings', 34, 45499, 'X-Men: The Last Stand (2006)'), ('Rosina OMaley', 35, 595, 'Beauty and the Beast (1991)'), ('Monsif Groundwater', 36, 6662, 'Pink Panther, The (1963)'), ('Kermit Winkley', 37, 1073, 'Willy Wonka & the Chocolate Factory (1971)'), ('Arvilla Gorse', 38, 736, 'Twister (1996)'), ('Jonhatan Clover', 39, 3911, 'Best in Show (2000)'), ('Loreta Copple', 40, 685, "It's My Party (1996)"), ('Genie Ewbank', 41, 150548, 'Sherlock: The Abominable Bride (2016)'), ('Grettel Keight', 42, 4686, "Weekend at Bernie's II (1993)"), ('Pino Gailey', 43, 1356, 'Star Trek: First Contact (1996)'), ('Xuehong Howey', 44, 1639, 'Chasing Amy (1997)'), ('Nati Holgate', 45, 54286, 'Bourne Ultimatum, The (2007)'), ('Betina Biltcliffe', 46, 595, 'Beauty and the Beast (1991)'), ('Zambra Wittleton', 47, 171011, 'Planet Earth II (2016)'), ('Puiu Hagen', 48, 8636, 'Spider-Man 2 (2004)'), ('Vladislav Hesket', 49, 168252, 'Logan (2017)'), ('Moner Fernee', 50, 190183, 'The Darkest Minds (2018)'), ('Guiayara Doyle', 51, 60487, "It's the Great Pumpkin, Charlie Brown (1966)"), ('Ghulam Dadswell', 52, 152081, 'Zootopia (2016)'), ('Laurea Mullet', 53, 4019, 'Finding Forrester (2000)'), ('Editha Pugh', 54, 639, 'Girl 6 (1996)'), ('Murat Dunckley', 55, 54286, 'Bourne Ultimatum, The (2007)'), ('Genara Rodley', 56, 786, 'Eraser (1996)'), ('Bilaly Baugh', 57, 5060, 'M*A*S*H (a.k.a. MASH) (1970)'), ('Abdessamad Pendrey', 58, 1073, 'Willy Wonka & the Chocolate Factory (1971)'), ('Shujing Orton', 59, 6460, 'Trial, The (Procès, Le) (1962)'), ('Fidencia Summerson', 60, 58559, 'Dark Knight, The (2008)'), ('Johanny Flemming', 61, 30707, 'Million Dollar Baby (2004)'), ('Fekri Key', 62, 187595, 'Solo: A Star Wars Story (2018)'), ('Fatemeh Downton', 63, 134853, 'Inside Out (2015)'), ('Jazael Nickols', 64, 46578, 'Little Miss Sunshine (2006)'), ('Joannie Bolderson', 65, 122904, 'Deadpool (2016)'), ('Shaomei Lowen', 66, 51255, 'Hot Fuzz (2007)'), ('Airong Hilbert', 67, 152081, 'Zootopia (2016)'), ('Norris Corling', 68, 176371, 'Blade Runner 2049 (2017)'), ('Pedrona Farigerty', 69, 4963, "Ocean's Eleven (2001)"), ('Ipar ...

# %% [markdown]
# ## Parte 4: Nested Loop Join
#
# Por último, en esta sección queremos que programen la misma consulta anterior pero con un *Nested Loop Join*. Su código debería verse de esta forma:
#
# ```python
# for usuario in usuarios:
#     for favorito in favoritos:
#         for pelicula in peliculas:
# ```
#
# Creen la función `nested_loop_join(usuarios, peliculas, favoritos)`. Esta función debería recibir una lista de usuarios, de películas y de favoritos. Debe retornar una lista de tuplas donde cada tupla debe ser de la forma `(nombre_usuario, userId, movieID, titulo_película)`.

# %%
# Aquí deberían crear la función:

# función de la forma más básica posible
def nested_loop_join(usuarios, peliculas, favoritos):
    ret = []
    for usuario in usuarios:
        for favorito in favoritos:
            for pelicula in peliculas: 
                if usuario[0] == favorito[0] and pelicula[0] == favorito[1]:
                    ret.append((usuario[1], usuario[0], pelicula[0], pelicula[1]))
    return ret

# una forma también básica, con un poco de lógica para comparar menos tuplas
def nested_loop_join_2(usuarios, peliculas, favoritos):
    ret = []
    for usuario in usuarios:
        for favorito in favoritos:
            if usuario[0] == favorito[0]:
                for pelicula in peliculas: 
                    if pelicula[0] == favorito[1]:
                        ret.append((usuario[1], usuario[0], pelicula[0], pelicula[1]))
    return ret

# %% [markdown]
# # Parte 5: Discusión
#
# Para esta sección debes discutir dos cosas:
#
# 1. Debes comparar el tiempo de ejecución que demora la función `nested_loop_join` con respecto a la función `join_tablas`. Primero debes considerar que los índices ya están creados para luego comparar los tiempos de ejecución considerando que tu *Join* primero crea los índices y después computa el resultado. Asegúrate de hacer este experimento con ambos datasets.
#
# 2. Considerando el tiempo que demoran los índices en crearse, ¿Por qué crees que los sistemas de bases de datos usan estas técnicas basadas en índices para computar consultas?
#
# Para tomar el tiempo de ejecución, recuerden que puedes utilizar la librería `time` de `Python` 🐍.

# %%
# Código y discusión
# Pueden agregar todas las casillas que quieran para desarrollar esta parte

# %%
# 1)
from timeit import default_timer as timer

# tiempo de ejecución sin crear los índices

users = list(map(tuple, usuarios.values))
movies = list(map(tuple, peliculas.values))
favorites = list(map(tuple, favoritos.values))

# RECOMIENDO NO DESCOMENTAR NI EJECUTAR, ES MUUUUUUUUUUUUY LENTO (> 10 minutos)
#start = timer()
#nested_loop_join(users, movies, favorites)
#end = timer()
#print("tiempo ejecución nested_loop_join:", end - start)

start = timer() 
nested_loop_join_2(users, movies, favorites)
end = timer() 
print("tiempo ejecución nested_loop_join_2:", end - start)

start = timer() 
join_tablas(usuarios_tree, peliculas_hash, favoritos_tree)
end = timer() 
print("tiempo ejecución join_tablas:", end - start)
# Out:
# tiempo ejecución nested_loop_join_2: 5.9060476999999985
# tiempo ejecución join_tablas: 0.0041886999999967145

# %%
# tiempo de ejecución creando índices

# RECOMIENDO NO DESCOMENTAR NI EJECUTAR, ES MUUUUUUUUUUUUY LENTO (> 10 minutos)
#start = timer()
#nested_loop_join(users, movies, favorites)
#end = timer()
#print("tiempo ejecución nested_loop_join:", end - start)

start = timer()
nested_loop_join_2(users, movies, favorites)
end = timer() 
print("tiempo ejecución nested_loop_join_2:", end - start)

start = timer()
# crear índices
usuarios_tree = OOBTree()
for index, row in usuarios.iterrows():
    usuarios_tree.update({row.id: NodoBTree((row.id, row.nombre))}) 
relacionar(list(usuarios_tree.keys()), usuarios_tree)
favoritos_tree = OOBTree()
for index, row in favoritos.iterrows():
    favoritos_tree.update({row.userID: NodoBTree((row.userID, row.movieId))})   
relacionar(list(favoritos_tree.keys()), favoritos_tree)
peliculas_hash = {p.movieId : (p.title, p.genres) for i, p in peliculas.iterrows()}
# ejecutar
join_tablas(usuarios_tree, peliculas_hash, favoritos_tree)
end = timer() 
print("tiempo ejecución join_tablas:", end - start)
# Out:
# tiempo ejecución nested_loop_join_2: 6.729810400000002
# tiempo ejecución join_tablas: 5.5220829999999985

# %% [markdown]
# 2)
# Como se puede apreciar con los resultados, realizar un nested loop join siempre es muy costoso de ejecutar. Si bien utilizando un buffer, podría ocurrir que el tiempo de ejecución del nested loop join fuera menor al tiempo total del join con B+ Tree + hash (ejecución + tiempo que se tarda en crear los índices), los sistemas de bases de datos utilizan estos sistemas pues no deben crear los índices cada vez que se realice una consulta. Lo anterior, nos permite que en la mayoría de los casos (para las consultas que están diseñadas estos índices, que debieran ser las más comunes) sólo debamos considerar el tiempo de ejecución, el cuál es notoriamente menor al tiempo en que se tardan en crear los índices.
